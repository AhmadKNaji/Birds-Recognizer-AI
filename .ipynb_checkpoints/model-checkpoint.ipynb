# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
batch_size = 32

img_height = 150

img_width = 150

train_dir = "./train"
test_dir = "./test"
valid_dir= "./valid"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=None,
  subset= None,
  seed= 42,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 70626 files belonging to 450 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  valid_dir,
  validation_split=None ,
  subset= None,
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2250 files belonging to 450 classes.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_dir,
  validation_split=None,
  subset=None,
  seed=42,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2250 files belonging to 450 classes.

# %%
bird_true_labels = train_ds.class_names

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(bird_true_labels[labels[i]])

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    tf.keras.layers.Conv2D(16, (5,5), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, (5,5), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (5,5), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(len(bird_true_labels))
])

# %%
model.compile(optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
m_tf = model.fit(train_ds,validation_data=val_ds,epochs=10)
# Out:
# Epoch 1/10
# 2208/2208 [==============================] - 51s 23ms/step - loss: 4.8620 - accuracy: 0.1000 - val_loss: 3.4939 - val_accuracy: 0.2591
# Epoch 2/10
# 2208/2208 [==============================] - 50s 22ms/step - loss: 3.2277 - accuracy: 0.3230 - val_loss: 2.5483 - val_accuracy: 0.4289
# Epoch 3/10
# 2208/2208 [==============================] - 50s 23ms/step - loss: 2.3817 - accuracy: 0.4697 - val_loss: 2.2616 - val_accuracy: 0.4822
# Epoch 4/10
# 2208/2208 [==============================] - 50s 23ms/step - loss: 1.8495 - accuracy: 0.5708 - val_loss: 2.4755 - val_accuracy: 0.4693
# Epoch 5/10
# 2208/2208 [==============================] - 49s 22ms/step - loss: 1.4275 - accuracy: 0.6551 - val_loss: 2.6135 - val_accuracy: 0.4693
# Epoch 6/10
# 2208/2208 [==============================] - 50s 23ms/step - loss: 1.0797 - accuracy: 0.7269 - val_loss: 3.1512 - val_accuracy: 0.4596
# Epoch 7/10
# 2208/2208 [==============================] - 50s 23ms/step - loss: 0.8278 - accuracy: 0.7819 - val_loss: 3.6951 - val_accuracy: 0.4613
# Epoch 8/10
# 2208/2208 [==============================] - 50s 22ms/step - loss: 0.6276 - accuracy: 0.8255 - val_loss: 4.1481 - val_accuracy: 0.4436
# Epoch 9/10
# 2208/2208 [==============================] - 49s 22ms/step - loss: 0.5182 - accuracy: 0.8521 - val_loss: 4.6812 - val_accuracy: 0.4316
# Epoch 10/10
# 2208/2208 [==============================] - 49s 22ms/step - loss: 0.4335 - accuracy: 0.8723 - val_loss: 5.2135 - val_accuracy: 0.4311

# %%
accuracy = m_tf.history['accuracy']

validation_accuracy = m_tf.history['val_accuracy']

loss = m_tf.history['loss']

validation_loss = m_tf.history['val_loss']

# %%
plt.figure(figsize=(20,20))

fig, ax = plt.subplots(nrows=2, ncols=1, sharex = True)

ax[0].plot(range(10), accuracy, label = 'Training Accuracy')
ax[0].plot(range(10), validation_accuracy, label = 'Validation Accuracy')
ax[0].legend(loc = 'lower right')
ax[0].set_title('Training & Validation Accuracy')

ax[1].plot(range(10), loss, label = 'Training Loss')
ax[1].plot(range(10), validation_loss, label = 'Validation Loss')
ax[1].legend(loc = 'lower right')
ax[1].set_title('Training & Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training & Validation Loss')

# %%
m_tf.model.evaluate(train_ds, verbose=True)
# Out:
# 2208/2208 [==============================] - 27s 12ms/step - loss: 0.9515 - accuracy: 0.7690
# [0.9515076279640198, 0.7690085768699646]

# %%
m_tf.model.evaluate(test_ds, verbose=True)
# Out:
# 71/71 [==============================] - 1s 14ms/step - loss: 4.9180 - accuracy: 0.4418
# [4.917954444885254, 0.441777765750885]

# %%
m_tf.model.evaluate(val_ds, verbose=True)
# Out:
# 71/71 [==============================] - 1s 14ms/step - loss: 5.2135 - accuracy: 0.4311
# [5.213495254516602, 0.43111109733581543]

# %%
m_tf.model.save('model.h5')
